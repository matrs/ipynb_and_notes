# %%
pwd
# Out:
# '/Users/cbib-02/Documents/Jupyter_Notebooks'

# %%
# %%bash
# cd /Users/cbib-02/Documents/TNT
# pwd
# ls -ltrh
# Out:
# /Users/cbib-02/Documents/TNT
# total 67944
# -rwxrwxrwx@  1 cbib-02  staff   6.2M Nov 10  2017 JCJR2.fasta
# -rw-r--r--   1 cbib-02  staff    83K Aug 14 15:54 pseudo_sp_vs_mandeleii.delta
# -rw-r--r--   1 cbib-02  staff    33K Aug 14 16:00 pseudo_sp_vs_mandeleii.dot.uniqueAnchorFiltered_l10000.delta.gz
# -rw-r--r--   1 cbib-02  staff    56K Aug 14 16:00 pseudo_sp_vs_mandeleii.dot.coords.idx
# -rw-r--r--   1 cbib-02  staff    38K Aug 14 16:00 pseudo_sp_vs_mandeleii.dot.coords
# -rw-r--r--   1 cbib-02  staff   202B Aug 14 16:00 nucmer.sh
# -rw-r--r--   1 cbib-02  staff   6.7M Aug 21 09:41 JCJR12.fasta
# -rw-r--r--@  1 cbib-02  staff   9.7K Sep 11 08:50 number_nitro-OYEs.ods
# -rw-r--r--@  1 cbib-02  staff   829B Sep 11 08:54 XenBs_angi.fasta
# -rw-r--r--   1 cbib-02  staff     0B Sep 11 09:03 AAF02539.1
# -rw-r--r--   1 cbib-02  staff     0B Sep 11 09:06 pseudo_xenb.fasta
# -rw-r--r--@  1 cbib-02  staff   2.5K Sep 11 09:09 xenBs.aln
# -rw-r--r--@  1 cbib-02  staff   411B Sep 11 09:25 xenb_jcjr2.fasta
# -rw-r--r--   1 cbib-02  staff   419B Sep 11 09:27 xenb_jcjr12.fasta
# drwxr-xr-x   5 cbib-02  staff   170B Sep 11 09:53 Aligments
# drwxr-xr-x   9 cbib-02  staff   306B Sep 13 13:18 JCJR2
# -rw-r--r--@  1 cbib-02  staff    20M Sep 13 15:57 gammaproteobacteria_odb9.tar.gz
# drwxr-xr-x  13 cbib-02  staff   442B Sep 14 08:44 JCJR12
# -rw-r--r--@  1 cbib-02  staff   1.5K Sep 24 11:54 xenbs_needle3.aln

# %%
import pandas as pd
import re
pd.set_option('max_colwidth', 2000)
# Out:
# /home/cbib/miniconda3/envs/bif/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/cbib/miniconda3/envs/bif/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
def Fastd_to_pandas(gff_file):
    '''Takes a gff file from `FASTD` and converts it to a pandas data frame with every column named
    as the GFF3 specification. It cleans the rows that have Nans in the `source` column (fasta sequences are appended 
    to the end of the file).  
    Input: GFF file name (full path expected)
    Output: Pandas Dataframe'''
    
    import pandas as pd
    
    col_names = ['seqid', 'source', 'type', 'start', 'end', 'score', 'strand', 'phase', 'attributes']
    gff_pd = pd.read_csv(gff_file, sep='\t', low_memory=False, comment='#', header=None, names=col_names)    
    gff_pd = gff_pd[~gff_pd['source'].isnull()]

    return gff_pd


def Unique_types_sources(gff_file):
    '''Takes a gff dataframe and prints the unique types to the stdout'''
    
    pd_dataframe = Fastd_to_pandas(gff_file)
    print('Unique types', pd_dataframe['type'].unique())
    print('Unique sources', pd_dataframe['source'].unique())
    
    return ""

def Anot_by_annotators(gff_file):
    '''Prints the number of annotation made by each software (annotator)'''
    
    df = Fastd_to_pandas(gff_file)
    sources = df['source'].unique()

    for source in sources:# Nans not included
        print(f'Number of entries from {source} ==>', df[df['source'] == source].shape[0])

# %%
def Type_counts(*gff_files, **species):    
    
    '''Returns the counts of each feature type (column named "type"). Names every column 
    with the specie name.
    Input: A list of file names *args and keyword args with the specia names. Order of keywords 
    matters, use the same as the list of gff_files
    Output: A data frame with type counts for each gff file'''
    
    import pandas as pd
    
    gff_files = gff_files
    
    gffs_pds = [Fastd_to_pandas(gff_file) for gff_file in gff_files]
    gffs_value_counts = [df["type"].value_counts() for df in gffs_pds]
    type_counts = pd.concat(gffs_value_counts, axis=1, sort=True)
    
    col_names = species
    type_counts.columns = col_names.values()
    return type_counts

# %%
def Most_common_products(gff_file, n=10, position_string=1):
    '''Takes in a dfast gff_file and pprints the n most common products.
    
    Input: gff_file, n (integer) which represents the number of top elements and position_string tells position
    of product qualifier.
    
    output: Prints to stdout the products and returns a counter dic with the  most 
    common products'''

    from pprint import pprint
    from collections import Counter
    
    pd = Fastd_to_pandas(gff_file)
    attribute_product= pd.iloc[: , 8].str.split(";").str[position_string]
    attribute_product= attribute_product.str.replace("product=", "")
    
    attribute_prod_dic = Counter()
    for element in attribute_product:
        attribute_prod_dic[element] += 1

    pprint(attribute_prod_dic.most_common()[:n])
    
    return attribute_prod_dic

# %%
def CDS_composition(*gff_files, ec_number_string ="EC_number", uniprot="UniProtKB", COG="COG", **species_names):
    '''Takes a list of GFF files, splits the attribute column (the last one) and returns it'''
    import pandas as pd
    
    gff_files = gff_files
    species = species_names.values()
    
    attributes_dic_list = []
    attributes_dic = {}
    ec_number_string = ec_number_string
    uniprot = uniprot

    product_types = [ec_number_string, uniprot, COG,"hypothetical protein"] 
    gffs_dfs = [Fastd_to_pandas(gff_file)["attributes"] for gff_file in gff_files]
    
    for df in gffs_dfs:
        gffs_attr_counts = {product_type : df.str.contains(product_type, case=False).sum() for product_type in product_types}
        attributes_dic_list.append(gffs_attr_counts)
        gffs_attr_counts = {}
    #print(type(attributes_dic_list),attributes_dic_list)
    df_attributes = pd.DataFrame(attributes_dic_list, index=species)
    df_attributes.columns =  ["COG", "UniProtKB", "EC number", "Hypothetical protein"]
        
    return round(df_attributes / gffs_dfs[0].shape[0] * 100, 3)

# %%
def Searching_atts(gff_file, patterns, dfast=True):
    '''Takes the attributes column, replaces the translation string if dfast=True, 
    the default (for prokka set it to False) and then searches for a list
    of patterns returning the number of ocurrences and indexes of each one
    
    input: list of patterns
    output: dictionary of each pattern and its indexes as a list of values'''
    
    import re
    from collections import defaultdict


    df = Fastd_to_pandas(gff_file)
    if dfast:
        atts = df.iloc[: , 8].str.replace("translation=[A-Z]+;", "")
        red_genes_locs = defaultdict()
    else:
        atts = df.iloc[: , 8]
        red_genes_locs = defaultdict()
    for red in potential_reds:
        #print(red, atts[atts.str.contains(red, flags=re.I)].shape)
        #print(atts[atts.str.contains(red, flags=re.I)].index, end="\n\n")
        red_genes_locs[red] = atts[atts.str.contains(red, flags=re.I)].index
    
    return(red_genes_locs)
    
        
potential_reds = ["nitroreductase", 'aldehyde.+oxidase', "amide.+dehydrogenase",\
                      "diaphorase","hydrogenase", "xanthine.+oxidase",\
                      "cytochrome.+reductase", "xen[A-Z]", 'PETN', "oxidoreductase",\
                      "xenobiotic", "OYE", "PETN", "flavin oxidoreductase", "nitro", 
                      "COG1902", "COG0778", "old yellow"]

# %%
#paths
JCJR2_path = '/Users/cbib-02/Documents/TNT/JCJR2/6666666.367937.gff'
JCJR12_path = '/Users/cbib-02/Documents/TNT/JCJR12/6666666.367945.gff'
JCJR2_path = '/run/media/cbib/Bionano/My_imac/TNT/JCJR12/'
JCJR12_path = '/Users/cbib-02/Documents/TNT/JCJR12/6666666.367945.gff'

# %%
JCJR2_df = Fastd_to_pandas(JCJR2_path)
JCJR12_df = Fastd_to_pandas(JCJR12_path)
JCJR2_df.head()
# Out:
#       seqid source type  start   end score strand phase  \
# 0  contig_1    FIG  CDS      1    63     .      -     1
# 1  contig_1    FIG  CDS    785  2413     .      +     2
# 2  contig_1    FIG  CDS   2425  4047     .      -     1
# 3  contig_1    FIG  CDS   4324  5280     .      -     1
# 4  contig_1    FIG  CDS   5342  6271     .      -     2
#
#                                                                                attributes
# 0                                   ID=fig|6666666.367937.peg.1;Name=hypothetical protein
# 1                                   ID=fig|6666666.367937.peg.2;Name=hypothetical protein
# 2  ID=fig|6666666.367937.peg.3;Name=Methyl-accepting chemotaxis sensor/transducer protein
# 3               ID=fig|6666666.367937.peg.4;Name=Uncharacterized methyltransferase PA1407
# 4                    ID=fig|6666666.367937.peg.5;Name=Auxin efflux carrier family protein

# %%
JCJR12_df
# Out:
#                    seqid source  type   start     end score strand phase  \
# 0     contig100|mandelii    FIG   CDS       1      93     .      -     1
# 1     contig100|mandelii    FIG   CDS     318     446     .      -     0
# 2     contig101|mandelii    FIG   CDS       1     444     .      +     1
# 3     contig102|mandelii    FIG   CDS       2     184     .      -     2
# 4     contig103|mandelii    FIG   CDS       3     443     .      -     0
# 5     contig106|mandelii    FIG   CDS       1     441     .      -     1
# 6     contig107|mandelii    FIG   CDS      20     442     .      +     2
# 7     contig109|mandelii    FIG   CDS       1     276     .      -     1
# 8     contig109|mandelii    FIG   CDS     369     440     .      +     0
# 9      contig10|mandelii    FIG   CDS       2     604     .      +     2
# 10     contig10|mandelii    FIG   CDS    1668    2174     .      -     0
# 11     contig10|mandelii    FIG   CDS    2197    2664     .      -     1
# 12     contig10|mandelii    FIG   CDS    2734    3771     .      -     1
# 13     contig10|mandelii    FIG   CDS    3833    4168     .      -     2
# 14     contig10|mandelii    FIG   CDS    4963    6594     .      +     1
# 15     contig10|mandelii    FIG   CDS    7283    8845     .      +     2
# 16     contig10|mandelii    FIG   CDS    9575    9727     .      -     2
# 17     contig10|mandelii    FIG   CDS   10103   11242     .      +     2
# 18     contig10|mandelii    FIG   CDS   11801   13231     .      +     2
# 19     contig10|mandelii    FIG   CDS   13457   14509     .      -     2
# 20     contig10|mandelii    FIG   CDS   14870   15178     .      -     2
# 21     contig10|mandelii    FIG   CDS   15405   16316     .      -     0
# 22     contig10|mandelii    FIG   CDS   16535   16930     .      +     2
# 23     contig10|mandelii    FIG   CDS   17181   17456     .      -     0
# 24     contig10|mandelii    FIG   CDS   17850   17969     .      +     0
# 25     contig10|mandelii    FIG   CDS   18175   18306     .      +     1
# 26     contig10|mandelii    FIG   CDS   18371   19174     .      -     2
# 27     contig10|mandelii    FIG   CDS   19258   20064     .      -     1
# 28     contig10|mandelii    FIG   CDS   20802   21935     .      -     0
# 29     contig10|mandelii    FIG   CDS   22435   22695     .      -     1
# ...                  ...    ...   ...     ...     ...   ...    ...   ...
# 6733    contig6|mandelii    FIG  tRNA  307975  308060     .      -     .
# 6734    contig6|mandelii    FIG  tRNA  307975  308060     .      -     .
# 6735    contig6|mandelii    FIG  tRNA  307975  308060     .      -     .
# 6736    contig7|mandelii    FIG  tRNA  201139  201215     .      -     .
# 6737    contig7|mandelii    FIG  tRNA  201139  201215     .      -     .
# 6738    contig7|mandelii    FIG  tRNA  201139  201215     .      -     .
# 6739    contig7|mandelii    FIG  tRNA  201421  201497     .      -     .
# 6740    contig7|mandelii    FIG  tRNA  201421  201497     .      -     .
# 6741    contig7|mandelii    FIG  tRNA  201421  201497     .      -     .
# 6742    contig7|mandelii    FIG  tRNA  334932  335005     .      -     .
# 6743    contig7|mandelii    FIG  tRNA  334932  335005     .      -     .
# 6744    contig7|mandelii    FIG  tRNA  334932  335005     .      -     .
# 6745    contig7|mandelii    FIG  tRNA  375418  375507     .      +     .
# 6746    contig7|mandelii    FIG  tRNA  375418  375507     .      +     .
# 6747    contig7|mandelii    FIG  tRNA  375418  375507     .      +     .
# 6748    contig8|mandelii    FIG  tRNA  205343  205419     .      +     .
# 6749    contig8|mandelii    FIG  tRNA  205343  205419     .      +     .
# 6750    contig8|mandelii    FIG  tRNA  205343  205419     .      +     .
# 6751    contig8|mandelii    FIG  tRNA  205452  205527     .      +     .
# 6752    contig8|mandelii    FIG  tRNA  205452  205527     .      +     .
# 6753    contig8|mandelii    FIG  tRNA  205452  205527     .      +     .
# 6754    contig8|mandelii    FIG  tRNA  205584  205668     .      +     .
# 6755    contig8|mandelii    FIG  tRNA  205584  205668     .      +     .
# 6756    contig8|mandelii    FIG  tRNA  205584  205668     .      +     .
# 6757    contig8|mandelii    FIG  tRNA  205747  205822     .      +     .
# 6758    contig8|mandelii    FIG  tRNA  205747  205822     .      +     .
# 6759    contig8|mandelii    FIG  tRNA  205747  205822     .      +     .
# 6760    contig8|mandelii    FIG  tRNA  212692  212769     .      +     .
# 6761    contig8|mandelii    FIG  tRNA  212692  212769     .      +     .
# 6762    contig8|mandelii    FIG  tRNA  212692  212769     .      +     .
#
#                                                                                                                                                                                                                           attributes
# 0                                                                                                                                                                              ID=fig|6666666.367945.peg.1;Name=hypothetical protein
# 1                                                                                                                                                                              ID=fig|6666666.367945.peg.2;Name=hypothetical protein
# 2                                                                                                                                                          ID=fig|6666666.367945.peg.3;Name=Phosphodiesterase/alkaline phosphatase D
# 3                                                                                                  ID=fig|6666666.367945.peg.4;Name=Multi antimicrobial extrusion protein (Na(+)/drug antiporter)%2C MATE family of MDR efflux pumps
# 4                                                                                                                                                                              ID=fig|6666666.367945.peg.5;Name=hypothetical protein
# 5                                                                                                                                                                            ID=fig|6666666.367945.peg.6;Name=Mobile element protein
# 6                                                                                                     ID=fig|6666666.367945.peg.7;Name=Deoxyguanosinetriphosphate triphosphohydrolase (EC 3.1.5.1);Ontology_term=KEGG_ENZYME:3.1.5.1
# 7                                                                                                                                                                 ID=fig|6666666.367945.peg.8;Name=SSU ribosomal protein S8p (S15Ae)
# 8                                                                                                                                                                              ID=fig|6666666.367945.peg.9;Name=hypothetical protein
# 9                                    ID=fig|6666666.367945.peg.10;Name=Xylulose-5-phosphate phosphoketolase (EC 4.1.2.9) @ Fructose-6-phosphate phosphoketolase (EC 4.1.2.22);Ontology_term=KEGG_ENZYME:4.1.2.9,KEGG_ENZYME:4.1.2.22
# 10                                                                                                                                                                            ID=fig|6666666.367945.peg.11;Name=hypothetical protein
# 11                                                                                                                                                                          ID=fig|6666666.367945.peg.12;Name=Mobile element protein
# 12                                                                                                                                                                          ID=fig|6666666.367945.peg.13;Name=Mobile element protein
# 13                                                                                                                                                                     ID=fig|6666666.367945.peg.14;Name=ISPpu14%2C transposase Orf2
# 14                                                                                                                                           ID=fig|6666666.367945.peg.15;Name=Methyl-accepting chemotaxis sensor/transducer protein
# 15                                                                                                                                                                            ID=fig|6666666.367945.peg.16;Name=hypothetical protein
# 16                                                                                                                                                                            ID=fig|6666666.367945.peg.17;Name=hypothetical protein
# 17                                                                                                                                 ID=fig|6666666.367945.peg.18;Name=Threonine dehydrogenase and related Zn-dependent dehydrogenases
# 18                                                                                                                                                                           ID=fig|6666666.367945.peg.19;Name=ISPsy6%2C transposase
# 19                                                                                                                                                         ID=fig|6666666.367945.peg.20;Name=Nucleoside-diphosphate-sugar epimerases
# 20                                                                                                   ID=fig|6666666.367945.peg.21;Name=Isoquinoline 1-oxidoreductase beta subunit (EC 1.3.99.16);Ontology_term=KEGG_ENZYME:1.3.99.16
# 21                                                                                                                                                                       ID=fig|6666666.367945.peg.22;Name=Transcriptional regulator
# 22                                                                                                                         ID=fig|6666666.367945.peg.23;Name=Lactoylglutathione lyase (EC 4.4.1.5);Ontology_term=KEGG_ENZYME:4.4.1.5
# 23                                                                                                                                                                            ID=fig|6666666.367945.peg.24;Name=hypothetical protein
# 24                                                                                                                                                                            ID=fig|6666666.367945.peg.25;Name=hypothetical protein
# 25    ID=fig|6666666.367945.peg.26;Name=Bifunctional protein: zinc-containing alcohol dehydrogenase%3B quinone oxidoreductase ( NADPH:quinone reductase) (EC 1.1.1.-)%3B Similar to arginate lyase;Ontology_term=KEGG_ENZYME:1.1.1.-
# 26                                                                                                                                                                            ID=fig|6666666.367945.peg.27;Name=hypothetical protein
# 27                                                                                                                                                                            ID=fig|6666666.367945.peg.28;Name=hypothetical protein
# 28                                                                                                                            ID=fig|6666666.367945.peg.29;Name=Serine-pyruvate aminotransferase/archaeal aspartate aminotransferase
# 29                                                                                                                                                                            ID=fig|6666666.367945.peg.30;Name=hypothetical protein
# ...                                                                                                                                                                                                                              ...
# 6733                                                                                                                                                                                  ID=fig|6666666.367945.rna.56;Name=tRNA-Leu-GAG
# 6734                                                                                                                                                                                  ID=fig|6666666.367945.rna.56;Name=tRNA-Leu-GAG
# 6735                                                                                                                                                                                  ID=fig|6666666.367945.rna.56;Name=tRNA-Leu-GAG
# 6736                                                                                                                                                                                  ID=fig|6666666.367945.rna.57;Name=tRNA-Met-CAT
# 6737                                                                                                                                                                                  ID=fig|6666666.367945.rna.57;Name=tRNA-Met-CAT
# 6738                                                                                                                                                                                  ID=fig|6666666.367945.rna.57;Name=tRNA-Met-CAT
# 6739                                                                                                                                                                                  ID=fig|6666666.367945.rna.58;Name=tRNA-Met-CAT
# 6740                                                                                                                                                                                  ID=fig|6666666.367945.rna.58;Name=tRNA-Met-CAT
# 6741                                                                                                                                                                                  ID=fig|6666666.367945.rna.58;Name=tRNA-Met-CAT
# 6742                                                                                                                                                                                  ID=fig|6666666.367945.rna.59;Name=tRNA-Gly-CCC
# 6743                                                                                                                                                                                  ID=fig|6666666.367945.rna.59;Name=tRNA-Gly-CCC
# 6744                                                                                                                                                                                  ID=fig|6666666.367945.rna.59;Name=tRNA-Gly-CCC
# 6745                                                                                                                                                                                  ID=fig|6666666.367945.rna.60;Name=tRNA-Ser-CGA
# 6746                                                                                                                                                                                  ID=fig|6666666.367945.rna.60;Name=tRNA-Ser-CGA
# 6747                                                                                                                                                                                  ID=fig|6666666.367945.rna.60;Name=tRNA-Ser-CGA
# 6748                                                                                                                                                                                  ID=fig|6666666.367945.rna.61;Name=tRNA-Arg-TCT
# 6749                                                                                                                                                                                  ID=fig|6666666.367945.rna.61;Name=tRNA-Arg-TCT
# 6750                                                                                                                                                                                  ID=fig|6666666.367945.rna.61;Name=tRNA-Arg-TCT
# 6751                                                                                                                                                                                  ID=fig|6666666.367945.rna.62;Name=tRNA-His-GTG
# 6752                                                                                                                                                                                  ID=fig|6666666.367945.rna.62;Name=tRNA-His-GTG
# 6753                                                                                                                                                                                  ID=fig|6666666.367945.rna.62;Name=tRNA-His-GTG
# 6754                                                                                                                                                                                  ID=fig|6666666.367945.rna.63;Name=tRNA-Leu-TAG
# 6755                                                                                                                                                                                  ID=fig|6666666.367945.rna.63;Name=tRNA-Leu-TAG
# 6756                                                                                                                                                                                  ID=fig|6666666.367945.rna.63;Name=tRNA-Leu-TAG
# 6757                                                                                                                                                                                  ID=fig|6666666.367945.rna.64;Name=tRNA-His-GTG
# 6758                                                                                                                                                                                  ID=fig|6666666.367945.rna.64;Name=tRNA-His-GTG
# 6759                                                                                                                                                                                  ID=fig|6666666.367945.rna.64;Name=tRNA-His-GTG
# 6760                                                                                                                                                                               ID=fig|6666666.367945.rna.65;Name=tRNA-Pseudo-GAG
# 6761                                                                                                                                                                               ID=fig|6666666.367945.rna.65;Name=tRNA-Pseudo-GAG
# 6762                                                                                                                                                                               ID=fig|6666666.367945.rna.65;Name=tRNA-Pseudo-GAG
#
# [6763 rows x 9 columns]

# %%
JCJR12_df.iloc[9, 8]
# Out:
# 'ID=fig|6666666.367945.peg.10;Name=Xylulose-5-phosphate phosphoketolase (EC 4.1.2.9) @ Fructose-6-phosphate phosphoketolase (EC 4.1.2.22);Ontology_term=KEGG_ENZYME:4.1.2.9,KEGG_ENZYME:4.1.2.22'

# %%
print(Unique_types_sources(JCJR12_path), Unique_types_sources(JCJR2_path))
# Out:
# Unique types ['CDS' 'tRNA' 'RNA']
# Unique sources ['FIG']
# Unique types ['CDS' 'tRNA' 'RNA']
# Unique sources ['FIG']

# %%
print(JCJR2_df.shape, JCJR12_df.shape)
# Out:
# (6299, 9) (6763, 9)

# %%
Type_counts(JCJR2_path, JCJR12_path, specie1='JCJR2', specie2='JCJR12')
# Out:
#       JCJR2  JCJR12
# CDS    6110    6568
# RNA      15      12
# tRNA    174     183

# %%
common_prods_jcjr2 = Most_common_products(JCJR2_path)
# Out:
# [('Name=hypothetical protein', 1534),
#  ('Name=Transcriptional regulator%2C LysR family', 64),
#  ('Name=Uncharacterized MFS-type transporter', 51),
#  ('Name=putative lipoprotein', 39),
#  ('Name=Transcriptional regulator%2C AraC family', 36),
#  ('Name=Mobile element protein', 36),
#  ('Name=putative membrane protein', 33),
#  ('Name=Methyl-accepting chemotaxis sensor/transducer protein', 30),
#  ('Name=Transcriptional regulator%2C AcrR family', 26),
#  ('Name=Acetyltransferase%2C GNAT family', 17)]

# %%
common_prods_jcjr12 = Most_common_products(JCJR12_path)
# Out:
# [('Name=hypothetical protein', 1569),
#  ('Name=Transcriptional regulator%2C LysR family', 75),
#  ('Name=putative lipoprotein', 46),
#  ('Name=Uncharacterized MFS-type transporter', 45),
#  ('Name=putative membrane protein', 42),
#  ('Name=Transcriptional regulator%2C AraC family', 40),
#  ('Name=Mobile element protein', 36),
#  ('Name=Two-component transcriptional response regulator%2C LuxR family', 28),
#  ('Name=Methyl-accepting chemotaxis sensor/transducer protein', 27),
#  ('Name=Transcriptional regulator%2C AcrR family', 21)]

# %%
JCJR2_df[JCJR2_df["attributes"].str.contains("COG")]
# Out:
#           seqid source type   start     end score strand phase  \
# 284    contig_1    FIG  CDS  308470  308712     .      -     1
# 524   contig_10    FIG  CDS   42104   42583     .      -     2
# 709   contig_11    FIG  CDS   32034   32573     .      +     0
# 1171  contig_13    FIG  CDS  116361  117131     .      +     0
# 1207  contig_13    FIG  CDS  149745  150584     .      +     0
# 1266  contig_14    FIG  CDS   16307   16603     .      -     2
# 2107  contig_19    FIG  CDS  120263  120703     .      +     2
# 2794  contig_22    FIG  CDS  124980  125570     .      -     0
# 3375  contig_28    FIG  CDS   56093   57340     .      -     2
# 3380  contig_28    FIG  CDS   60922   61884     .      -     1
# 4565   contig_4    FIG  CDS  169785  170114     .      -     0
# 4566   contig_4    FIG  CDS  170111  171028     .      -     2
# 4568   contig_4    FIG  CDS  172509  173054     .      -     0
# 4954   contig_5    FIG  CDS   53541   53756     .      -     0
# 4971   contig_5    FIG  CDS   69596   70621     .      -     2
#
#                                                                                                                  attributes
# 284                                                                         ID=fig|6666666.367937.peg.285;Name=COGs COG2002
# 524                                                                         ID=fig|6666666.367937.peg.525;Name=COGs COG3558
# 709                                                   ID=fig|6666666.367937.peg.710;Name=Putative analog of CcoH%2C COG3198
# 1171                                       ID=fig|6666666.367937.peg.1172;Name=COG2041: Sulfite oxidase and related enzymes
# 1207                                                                       ID=fig|6666666.367937.peg.1208;Name=COGs COG3777
# 1266                                                                       ID=fig|6666666.367937.peg.1267;Name=COGs COG3492
# 2107                                            ID=fig|6666666.367937.peg.2108;Name=Universal stress protein family COG0589
# 2794                   ID=fig|6666666.367937.peg.2795;Name=FIG000605: protein co-occurring with transport systems (COG1739)
# 3375                                        ID=fig|6666666.367937.peg.3376;Name=COG2907: Amine oxidase%2C flavin-containing
# 3380  ID=fig|6666666.367937.peg.3381;Name=COG1683: Uncharacterized conserved protein / FIG143828: Hypothetical protein YbgA
# 4565                                       ID=fig|6666666.367937.peg.4566;Name=Putative lipoprotein in cluster with COG2110
# 4566                    ID=fig|6666666.367937.peg.4567;Name=Hydrolase of the alpha/beta superfamily in cluster with COG2110
# 4568        ID=fig|6666666.367937.peg.4569;Name=Putative lipoprotein%2C specific for Pseudomonas%2C in cluster with COG2110
# 4954                                                   ID=fig|6666666.367937.peg.4955;Name=Dodecin (COG3360) Flavin-binding
# 4971                                ID=fig|6666666.367937.peg.4972;Name=Uncharacterized protein with LysM domain%2C COG1652

# %% [markdown]
# **EC numbers in `Rast` are represented by the strings `EC xx.xx.xx`. It seems almost always there's a space between the string `EC` and the numbers but in one case there wasn't, look below**

# %%
JCJR2_df[JCJR2_df["attributes"].str.contains('\(EC\S', flags=re.I)]
# Out:
#          seqid source type   start     end score strand phase  \
# 5801  contig_8    FIG  CDS  128314  129597     .      +     1
#
#                                                                                                                attributes
# 5801  ID=fig|6666666.367937.peg.5802;Name=Gamma-glutamyl-putrescine oxidase (EC1.4.3.-);Ontology_term=KEGG_ENZYME:1.4.3.-

# %%
JCJR2_df[JCJR2_df["attributes"].str.contains('\(EC\s', flags=re.I)]
# Out:
#          seqid source type   start     end score strand phase  \
# 5     contig_1    FIG  CDS    6525    7559     .      +     0
# 13    contig_1    FIG  CDS   14362   14703     .      -     1
# 18    contig_1    FIG  CDS   18901   19680     .      +     1
# 20    contig_1    FIG  CDS   21899   22876     .      +     2
# 21    contig_1    FIG  CDS   22933   23952     .      +     1
# 22    contig_1    FIG  CDS   23949   25055     .      +     0
# 25    contig_1    FIG  CDS   27491   28639     .      -     2
# 28    contig_1    FIG  CDS   29327   30403     .      -     2
# 30    contig_1    FIG  CDS   30890   31696     .      -     2
# 39    contig_1    FIG  CDS   40490   41665     .      +     2
# 41    contig_1    FIG  CDS   43374   45350     .      -     0
# 46    contig_1    FIG  CDS   48130   48567     .      +     1
# 53    contig_1    FIG  CDS   53210   55576     .      +     2
# 67    contig_1    FIG  CDS   68580   70016     .      +     0
# 68    contig_1    FIG  CDS   70013   71230     .      +     2
# 72    contig_1    FIG  CDS   73648   74244     .      +     1
# 73    contig_1    FIG  CDS   74311   74622     .      +     1
# 81    contig_1    FIG  CDS   82639   83517     .      +     1
# 95    contig_1    FIG  CDS   99957  101219     .      +     0
# 102   contig_1    FIG  CDS  107357  109519     .      +     2
# 103   contig_1    FIG  CDS  109667  111109     .      +     2
# 118   contig_1    FIG  CDS  122937  123704     .      +     0
# 119   contig_1    FIG  CDS  123729  124934     .      +     0
# 120   contig_1    FIG  CDS  125019  125792     .      +     0
# 134   contig_1    FIG  CDS  142204  144165     .      -     1
# 135   contig_1    FIG  CDS  144162  144986     .      -     0
# 136   contig_1    FIG  CDS  145012  146619     .      -     1
# 137   contig_1    FIG  CDS  146686  147849     .      -     1
# 139   contig_1    FIG  CDS  148555  149454     .      -     1
# 144   contig_1    FIG  CDS  154150  154962     .      -     1
# ...        ...    ...  ...     ...     ...   ...    ...   ...
# 5944  contig_9    FIG  CDS   32799   34046     .      +     0
# 5945  contig_9    FIG  CDS   34050   34880     .      +     0
# 5948  contig_9    FIG  CDS   36520   37212     .      +     1
# 5963  contig_9    FIG  CDS   54001   54573     .      +     1
# 5968  contig_9    FIG  CDS   60030   60680     .      -     0
# 5970  contig_9    FIG  CDS   61447   63498     .      +     1
# 5975  contig_9    FIG  CDS   67520   68251     .      +     2
# 5978  contig_9    FIG  CDS   71068   72192     .      +     1
# 5980  contig_9    FIG  CDS   72362   73954     .      +     2
# 5982  contig_9    FIG  CDS   74551   75438     .      +     1
# 5987  contig_9    FIG  CDS   78249   79148     .      +     0
# 5994  contig_9    FIG  CDS   84847   86994     .      +     1
# 6000  contig_9    FIG  CDS   91183   92133     .      -     1
# 6002  contig_9    FIG  CDS   92532   95294     .      +     0
# 6009  contig_9    FIG  CDS  101278  102060     .      +     1
# 6033  contig_9    FIG  CDS  126601  128676     .      -     1
# 6041  contig_9    FIG  CDS  134564  136669     .      -     2
# 6042  contig_9    FIG  CDS  136730  136993     .      -     2
# 6043  contig_9    FIG  CDS  137141  137761     .      -     2
# 6045  contig_9    FIG  CDS  138940  139662     .      +     1
# 6059  contig_9    FIG  CDS  149939  150949     .      +     2
# 6060  contig_9    FIG  CDS  150966  153179     .      +     0
# 6061  contig_9    FIG  CDS  153166  154668     .      -     1
# 6070  contig_9    FIG  CDS  160356  161438     .      -     0
# 6076  contig_9    FIG  CDS  167057  168400     .      -     2
# 6080  contig_9    FIG  CDS  170045  170647     .      +     2
# 6089  contig_9    FIG  CDS  177341  178807     .      -     2
# 6099  contig_9    FIG  CDS  186898  188265     .      -     1
# 6101  contig_9    FIG  CDS  189406  190554     .      +     1
# 6102  contig_9    FIG  CDS  190681  191979     .      +     1
#
#                                                                                                                                                                                                                             attributes
# 5                                                                                                                            ID=fig|6666666.367937.peg.6;Name=Selenide%2Cwater dikinase (EC 2.7.9.3);Ontology_term=KEGG_ENZYME:2.7.9.3
# 13                                                                                                              ID=fig|6666666.367937.peg.14;Name=Peptidylprolyl isomerase%2C FKBP-type (EC 5.2.1.8);Ontology_term=KEGG_ENZYME:5.2.1.8
# 18                                                                      ID=fig|6666666.367937.peg.19;Name=2%2C3-butanediol dehydrogenase%2C S-alcohol forming%2C (S)-acetoin-specific (EC 1.1.1.76);Ontology_term=KEGG_ENZYME:1.1.1.76
# 20                                                                                               ID=fig|6666666.367937.peg.21;Name=Acetoin dehydrogenase E1 component alpha-subunit (EC 2.3.1.190);Ontology_term=KEGG_ENZYME:2.3.1.190
# 21                                                                                                ID=fig|6666666.367937.peg.22;Name=Acetoin dehydrogenase E1 component beta-subunit (EC 2.3.1.190);Ontology_term=KEGG_ENZYME:2.3.1.190
# 22                                                               ID=fig|6666666.367937.peg.23;Name=Dihydrolipoamide acetyltransferase component (E2) of acetoin dehydrogenase complex (EC 2.3.1.12);Ontology_term=KEGG_ENZYME:2.3.1.12
# 25                                                                                                                ID=fig|6666666.367937.peg.26;Name=Cystathionine beta-lyase%2C type II (EC 4.4.1.8);Ontology_term=KEGG_ENZYME:4.4.1.8
# 28                                                                              ID=fig|6666666.367937.peg.29;Name=Chemotaxis response regulator protein-glutamate methylesterase CheB (EC 3.1.1.61);Ontology_term=KEGG_ENZYME:3.1.1.61
# 30                                                                                                        ID=fig|6666666.367937.peg.31;Name=Chemotaxis protein methyltransferase CheR (EC 2.1.1.80);Ontology_term=KEGG_ENZYME:2.1.1.80
# 39                                                                                                                 ID=fig|6666666.367937.peg.40;Name=Acetylornithine aminotransferase (EC 2.6.1.11);Ontology_term=KEGG_ENZYME:2.6.1.11
# 41                                                                                                                            ID=fig|6666666.367937.peg.42;Name=DNA topoisomerase III (EC 5.99.1.2);Ontology_term=KEGG_ENZYME:5.99.1.2
# 46                                                                              ID=fig|6666666.367937.peg.47;Name=Arsenate reductase (EC 1.20.4.1) glutaredoxin-coupled%2C glutaredoxin-like family;Ontology_term=KEGG_ENZYME:1.20.4.1
# 53                                                                                                                                  ID=fig|6666666.367937.peg.54;Name=DNA polymerase II (EC 2.7.7.7);Ontology_term=KEGG_ENZYME:2.7.7.7
# 67                                                                                                               ID=fig|6666666.367937.peg.68;Name=D-2-hydroxyglutarate dehydrogenase (EC 1.1.99.2);Ontology_term=KEGG_ENZYME:1.1.99.2
# 68                                                                                                                         ID=fig|6666666.367937.peg.69;Name=Aspartate aminotransferase (EC 2.6.1.1);Ontology_term=KEGG_ENZYME:2.6.1.1
# 72                                                                                                                         ID=fig|6666666.367937.peg.73;Name=Cysteine dioxygenase (EC 1.13.11.20);Ontology_term=KEGG_ENZYME:1.13.11.20
# 73                                                                                                                        ID=fig|6666666.367937.peg.74;Name=Glutathione S-transferase (EC 2.5.1.18);Ontology_term=KEGG_ENZYME:2.5.1.18
# 81                                                                                                                               ID=fig|6666666.367937.peg.82;Name=L-arabinolactonase (EC 3.1.1.15);Ontology_term=KEGG_ENZYME:3.1.1.15
# 95                                                                                                                              ID=fig|6666666.367937.peg.96;Name=Beta-ureidopropionase (EC 3.5.1.6);Ontology_term=KEGG_ENZYME:3.5.1.6
# 102                                                                                        ID=fig|6666666.367937.peg.103;Name=Quino(hemo)protein alcohol dehydrogenase%2C PQQ-dependent (EC 1.1.2.8);Ontology_term=KEGG_ENZYME:1.1.2.8
# 103                                                     ID=fig|6666666.367937.peg.104;Name=Aldehyde dehydrogenase A (EC 1.2.1.22) @ Glycolaldehyde dehydrogenase (EC 1.2.1.21);Ontology_term=KEGG_ENZYME:1.2.1.22,KEGG_ENZYME:1.2.1.21
# 118                                                                                       ID=fig|6666666.367937.peg.119;Name=3-hydroxyacyl-CoA dehydrogenase [isoleucine degradation] (EC 1.1.1.35);Ontology_term=KEGG_ENZYME:1.1.1.35
# 119                                                        ID=fig|6666666.367937.peg.120;Name=3-ketoacyl-CoA thiolase (EC 2.3.1.16) @ Acetyl-CoA acetyltransferase (EC 2.3.1.9);Ontology_term=KEGG_ENZYME:2.3.1.16,KEGG_ENZYME:2.3.1.9
# 120                                                           ID=fig|6666666.367937.peg.121;Name=Enoyl-CoA hydratase (EC 4.2.1.17) > degradation of branched-chain amino acids and alpha-keto acids;Ontology_term=KEGG_ENZYME:4.2.1.17
# 134                                                                                         ID=fig|6666666.367937.peg.135;Name=Methylcrotonyl-CoA carboxylase biotin-containing subunit (EC 6.4.1.4);Ontology_term=KEGG_ENZYME:6.4.1.4
# 135                                                                                                                 ID=fig|6666666.367937.peg.136;Name=Methylglutaconyl-CoA hydratase (EC 4.2.1.18);Ontology_term=KEGG_ENZYME:4.2.1.18
# 136                                                                                      ID=fig|6666666.367937.peg.137;Name=Methylcrotonyl-CoA carboxylase carboxyl transferase subunit (EC 6.4.1.4);Ontology_term=KEGG_ENZYME:6.4.1.4
# 137                                                                                                                     ID=fig|6666666.367937.peg.138;Name=Isovaleryl-CoA dehydrogenase (EC 1.3.8.4);Ontology_term=KEGG_ENZYME:1.3.8.4
# 139                                                                                                                  ID=fig|6666666.367937.peg.140;Name=Hydroxymethylglutaryl-CoA lyase (EC 4.1.3.4);Ontology_term=KEGG_ENZYME:4.1.3.4
# 144                                                                                                                       ID=fig|6666666.367937.peg.145;Name=Exodeoxyribonuclease III (EC 3.1.11.2);Ontology_term=KEGG_ENZYME:3.1.11.2
# ...                                                                                                                                                                                                                                ...
# 5944                                                                                                                ID=fig|6666666.367937.peg.5945;Name=Diaminopimelate decarboxylase (EC 4.1.1.20);Ontology_term=KEGG_ENZYME:4.1.1.20
# 5945                                                                                                                      ID=fig|6666666.367937.peg.5946;Name=Diaminopimelate epimerase (EC 5.1.1.7);Ontology_term=KEGG_ENZYME:5.1.1.7
# 5948                                                                                                               ID=fig|6666666.367937.peg.5949;Name=2-haloalkanoic acid dehalogenase (EC 3.8.1.2);Ontology_term=KEGG_ENZYME:3.8.1.2
# 5963                                                                                                           ID=fig|6666666.367937.peg.5964;Name=Xanthine phosphoribosyltransferase (EC 2.4.2.22);Ontology_term=KEGG_ENZYME:2.4.2.22
# 5968                                                                                                                 ID=fig|6666666.367937.peg.5969;Name=Phosphoglycolate phosphatase (EC 3.1.3.18);Ontology_term=KEGG_ENZYME:3.1.3.18
# 5970                                                                                                                           ID=fig|6666666.367937.peg.5971;Name=Oligopeptidase A (EC 3.4.24.70);Ontology_term=KEGG_ENZYME:3.4.24.70
# 5975                                                                                                               ID=fig|6666666.367937.peg.5976;Name=Carbonic anhydrase%2C beta class (EC 4.2.1.1);Ontology_term=KEGG_ENZYME:4.2.1.1
# 5978                                                                                                            ID=fig|6666666.367937.peg.5979;Name=Cytochrome c oxidase polypeptide II (EC 1.9.3.1);Ontology_term=KEGG_ENZYME:1.9.3.1
# 5980                                                                                                             ID=fig|6666666.367937.peg.5981;Name=Cytochrome c oxidase polypeptide I (EC 1.9.3.1);Ontology_term=KEGG_ENZYME:1.9.3.1
# 5982                                                                                                           ID=fig|6666666.367937.peg.5983;Name=Cytochrome c oxidase polypeptide III (EC 1.9.3.1);Ontology_term=KEGG_ENZYME:1.9.3.1
# 5987                                                                                 ID=fig|6666666.367937.peg.5988;Name=Heme O synthase%2C protoheme IX farnesyltransferase (EC 2.5.1.-) COX10-CtaB;Ontology_term=KEGG_ENZYME:2.5.1.-
# 5994                                                                                                         ID=fig|6666666.367937.peg.5995;Name=Catalase KatE-intracellular protease (EC 1.11.1.6);Ontology_term=KEGG_ENZYME:1.11.1.6
# 6000                                                                                                                            ID=fig|6666666.367937.peg.6001;Name=Homoserine kinase (EC 2.7.1.39);Ontology_term=KEGG_ENZYME:2.7.1.39
# 6002                                                                                                                               ID=fig|6666666.367937.peg.6003;Name=DNA polymerase I (EC 2.7.7.7);Ontology_term=KEGG_ENZYME:2.7.7.7
# 6009                                                         ID=fig|6666666.367937.peg.6010;Name=N-acetylmuramoyl-L-alanine amidase (EC 3.5.1.28) @ 1%2C6-anhydro-N-acetylmuramyl-L-alanine amidase;Ontology_term=KEGG_ENZYME:3.5.1.28
# 6033                                                                                                              ID=fig|6666666.367937.peg.6034;Name=ATP-dependent DNA helicase RecG (EC 3.6.4.12);Ontology_term=KEGG_ENZYME:3.6.4.12
# 6041  ID=fig|6666666.367937.peg.6042;Name=Guanosine-3'%2C5'-bis(diphosphate) 3'-pyrophosphohydrolase (EC 3.1.7.2) / GTP pyrophosphokinase (EC 2.7.6.5)%2C (p)ppGpp synthetase II;Ontology_term=KEGG_ENZYME:3.1.7.2,KEGG_ENZYME:2.7.6.5
# 6042                                                                                                      ID=fig|6666666.367937.peg.6043;Name=DNA-directed RNA polymerase omega subunit (EC 2.7.7.6);Ontology_term=KEGG_ENZYME:2.7.7.6
# 6043                                                                                                                               ID=fig|6666666.367937.peg.6044;Name=Guanylate kinase (EC 2.7.4.8);Ontology_term=KEGG_ENZYME:2.7.4.8
# 6045                                                                                                                              ID=fig|6666666.367937.peg.6046;Name=Ribonuclease PH (EC 2.7.7.56);Ontology_term=KEGG_ENZYME:2.7.7.56
# 6059                                                                                                                     ID=fig|6666666.367937.peg.6060;Name=Porphobilinogen synthase (EC 4.2.1.24);Ontology_term=KEGG_ENZYME:4.2.1.24
# 6060                                                                                                                           ID=fig|6666666.367937.peg.6061;Name=Polyphosphate kinase (EC 2.7.4.1);Ontology_term=KEGG_ENZYME:2.7.4.1
# 6061                                                                                                                           ID=fig|6666666.367937.peg.6062;Name=Exopolyphosphatase (EC 3.6.1.11);Ontology_term=KEGG_ENZYME:3.6.1.11
# 6070                                                                                   ID=fig|6666666.367937.peg.6071;Name=Aminomethyltransferase (glycine cleavage system T protein) (EC 2.1.2.10);Ontology_term=KEGG_ENZYME:2.1.2.10
# 6076                                                                                                                       ID=fig|6666666.367937.peg.6077;Name=Xaa-Pro aminopeptidase (EC 3.4.11.9);Ontology_term=KEGG_ENZYME:3.4.11.9
# 6080                                                                                                          ID=fig|6666666.367937.peg.6081;Name=5-formyltetrahydrofolate cyclo-ligase (EC 6.3.3.2);Ontology_term=KEGG_ENZYME:6.3.3.2
# 6089                                                                                                 ID=fig|6666666.367937.peg.6090;Name=3-polyprenyl-4-hydroxybenzoate carboxy-lyase (EC 4.1.1.98);Ontology_term=KEGG_ENZYME:4.1.1.98
# 6099                                                                                                                     ID=fig|6666666.367937.peg.6100;Name=Inorganic triphosphatase (EC 3.6.1.25);Ontology_term=KEGG_ENZYME:3.6.1.25
# 6101                                                                                                                  ID=fig|6666666.367937.peg.6102;Name=Acetylornithine deacetylase (EC 3.5.1.16);Ontology_term=KEGG_ENZYME:3.5.1.16
# 6102                                                                                                                     ID=fig|6666666.367937.peg.6103;Name=N-acetylglutamate synthase (EC 2.3.1.1);Ontology_term=KEGG_ENZYME:2.3.1.1
#
# [1348 rows x 9 columns]

# %%
JCJR2_df[JCJR2_df["attributes"].str.contains('\(EC', flags=re.I)]
# Out:
#          seqid source type   start     end score strand phase  \
# 5     contig_1    FIG  CDS    6525    7559     .      +     0
# 13    contig_1    FIG  CDS   14362   14703     .      -     1
# 18    contig_1    FIG  CDS   18901   19680     .      +     1
# 20    contig_1    FIG  CDS   21899   22876     .      +     2
# 21    contig_1    FIG  CDS   22933   23952     .      +     1
# 22    contig_1    FIG  CDS   23949   25055     .      +     0
# 25    contig_1    FIG  CDS   27491   28639     .      -     2
# 28    contig_1    FIG  CDS   29327   30403     .      -     2
# 30    contig_1    FIG  CDS   30890   31696     .      -     2
# 39    contig_1    FIG  CDS   40490   41665     .      +     2
# 41    contig_1    FIG  CDS   43374   45350     .      -     0
# 46    contig_1    FIG  CDS   48130   48567     .      +     1
# 53    contig_1    FIG  CDS   53210   55576     .      +     2
# 67    contig_1    FIG  CDS   68580   70016     .      +     0
# 68    contig_1    FIG  CDS   70013   71230     .      +     2
# 72    contig_1    FIG  CDS   73648   74244     .      +     1
# 73    contig_1    FIG  CDS   74311   74622     .      +     1
# 81    contig_1    FIG  CDS   82639   83517     .      +     1
# 95    contig_1    FIG  CDS   99957  101219     .      +     0
# 102   contig_1    FIG  CDS  107357  109519     .      +     2
# 103   contig_1    FIG  CDS  109667  111109     .      +     2
# 118   contig_1    FIG  CDS  122937  123704     .      +     0
# 119   contig_1    FIG  CDS  123729  124934     .      +     0
# 120   contig_1    FIG  CDS  125019  125792     .      +     0
# 134   contig_1    FIG  CDS  142204  144165     .      -     1
# 135   contig_1    FIG  CDS  144162  144986     .      -     0
# 136   contig_1    FIG  CDS  145012  146619     .      -     1
# 137   contig_1    FIG  CDS  146686  147849     .      -     1
# 139   contig_1    FIG  CDS  148555  149454     .      -     1
# 144   contig_1    FIG  CDS  154150  154962     .      -     1
# ...        ...    ...  ...     ...     ...   ...    ...   ...
# 5944  contig_9    FIG  CDS   32799   34046     .      +     0
# 5945  contig_9    FIG  CDS   34050   34880     .      +     0
# 5948  contig_9    FIG  CDS   36520   37212     .      +     1
# 5963  contig_9    FIG  CDS   54001   54573     .      +     1
# 5968  contig_9    FIG  CDS   60030   60680     .      -     0
# 5970  contig_9    FIG  CDS   61447   63498     .      +     1
# 5975  contig_9    FIG  CDS   67520   68251     .      +     2
# 5978  contig_9    FIG  CDS   71068   72192     .      +     1
# 5980  contig_9    FIG  CDS   72362   73954     .      +     2
# 5982  contig_9    FIG  CDS   74551   75438     .      +     1
# 5987  contig_9    FIG  CDS   78249   79148     .      +     0
# 5994  contig_9    FIG  CDS   84847   86994     .      +     1
# 6000  contig_9    FIG  CDS   91183   92133     .      -     1
# 6002  contig_9    FIG  CDS   92532   95294     .      +     0
# 6009  contig_9    FIG  CDS  101278  102060     .      +     1
# 6033  contig_9    FIG  CDS  126601  128676     .      -     1
# 6041  contig_9    FIG  CDS  134564  136669     .      -     2
# 6042  contig_9    FIG  CDS  136730  136993     .      -     2
# 6043  contig_9    FIG  CDS  137141  137761     .      -     2
# 6045  contig_9    FIG  CDS  138940  139662     .      +     1
# 6059  contig_9    FIG  CDS  149939  150949     .      +     2
# 6060  contig_9    FIG  CDS  150966  153179     .      +     0
# 6061  contig_9    FIG  CDS  153166  154668     .      -     1
# 6070  contig_9    FIG  CDS  160356  161438     .      -     0
# 6076  contig_9    FIG  CDS  167057  168400     .      -     2
# 6080  contig_9    FIG  CDS  170045  170647     .      +     2
# 6089  contig_9    FIG  CDS  177341  178807     .      -     2
# 6099  contig_9    FIG  CDS  186898  188265     .      -     1
# 6101  contig_9    FIG  CDS  189406  190554     .      +     1
# 6102  contig_9    FIG  CDS  190681  191979     .      +     1
#
#                                                                                                                                                                                                                             attributes
# 5                                                                                                                            ID=fig|6666666.367937.peg.6;Name=Selenide%2Cwater dikinase (EC 2.7.9.3);Ontology_term=KEGG_ENZYME:2.7.9.3
# 13                                                                                                              ID=fig|6666666.367937.peg.14;Name=Peptidylprolyl isomerase%2C FKBP-type (EC 5.2.1.8);Ontology_term=KEGG_ENZYME:5.2.1.8
# 18                                                                      ID=fig|6666666.367937.peg.19;Name=2%2C3-butanediol dehydrogenase%2C S-alcohol forming%2C (S)-acetoin-specific (EC 1.1.1.76);Ontology_term=KEGG_ENZYME:1.1.1.76
# 20                                                                                               ID=fig|6666666.367937.peg.21;Name=Acetoin dehydrogenase E1 component alpha-subunit (EC 2.3.1.190);Ontology_term=KEGG_ENZYME:2.3.1.190
# 21                                                                                                ID=fig|6666666.367937.peg.22;Name=Acetoin dehydrogenase E1 component beta-subunit (EC 2.3.1.190);Ontology_term=KEGG_ENZYME:2.3.1.190
# 22                                                               ID=fig|6666666.367937.peg.23;Name=Dihydrolipoamide acetyltransferase component (E2) of acetoin dehydrogenase complex (EC 2.3.1.12);Ontology_term=KEGG_ENZYME:2.3.1.12
# 25                                                                                                                ID=fig|6666666.367937.peg.26;Name=Cystathionine beta-lyase%2C type II (EC 4.4.1.8);Ontology_term=KEGG_ENZYME:4.4.1.8
# 28                                                                              ID=fig|6666666.367937.peg.29;Name=Chemotaxis response regulator protein-glutamate methylesterase CheB (EC 3.1.1.61);Ontology_term=KEGG_ENZYME:3.1.1.61
# 30                                                                                                        ID=fig|6666666.367937.peg.31;Name=Chemotaxis protein methyltransferase CheR (EC 2.1.1.80);Ontology_term=KEGG_ENZYME:2.1.1.80
# 39                                                                                                                 ID=fig|6666666.367937.peg.40;Name=Acetylornithine aminotransferase (EC 2.6.1.11);Ontology_term=KEGG_ENZYME:2.6.1.11
# 41                                                                                                                            ID=fig|6666666.367937.peg.42;Name=DNA topoisomerase III (EC 5.99.1.2);Ontology_term=KEGG_ENZYME:5.99.1.2
# 46                                                                              ID=fig|6666666.367937.peg.47;Name=Arsenate reductase (EC 1.20.4.1) glutaredoxin-coupled%2C glutaredoxin-like family;Ontology_term=KEGG_ENZYME:1.20.4.1
# 53                                                                                                                                  ID=fig|6666666.367937.peg.54;Name=DNA polymerase II (EC 2.7.7.7);Ontology_term=KEGG_ENZYME:2.7.7.7
# 67                                                                                                               ID=fig|6666666.367937.peg.68;Name=D-2-hydroxyglutarate dehydrogenase (EC 1.1.99.2);Ontology_term=KEGG_ENZYME:1.1.99.2
# 68                                                                                                                         ID=fig|6666666.367937.peg.69;Name=Aspartate aminotransferase (EC 2.6.1.1);Ontology_term=KEGG_ENZYME:2.6.1.1
# 72                                                                                                                         ID=fig|6666666.367937.peg.73;Name=Cysteine dioxygenase (EC 1.13.11.20);Ontology_term=KEGG_ENZYME:1.13.11.20
# 73                                                                                                                        ID=fig|6666666.367937.peg.74;Name=Glutathione S-transferase (EC 2.5.1.18);Ontology_term=KEGG_ENZYME:2.5.1.18
# 81                                                                                                                               ID=fig|6666666.367937.peg.82;Name=L-arabinolactonase (EC 3.1.1.15);Ontology_term=KEGG_ENZYME:3.1.1.15
# 95                                                                                                                              ID=fig|6666666.367937.peg.96;Name=Beta-ureidopropionase (EC 3.5.1.6);Ontology_term=KEGG_ENZYME:3.5.1.6
# 102                                                                                        ID=fig|6666666.367937.peg.103;Name=Quino(hemo)protein alcohol dehydrogenase%2C PQQ-dependent (EC 1.1.2.8);Ontology_term=KEGG_ENZYME:1.1.2.8
# 103                                                     ID=fig|6666666.367937.peg.104;Name=Aldehyde dehydrogenase A (EC 1.2.1.22) @ Glycolaldehyde dehydrogenase (EC 1.2.1.21);Ontology_term=KEGG_ENZYME:1.2.1.22,KEGG_ENZYME:1.2.1.21
# 118                                                                                       ID=fig|6666666.367937.peg.119;Name=3-hydroxyacyl-CoA dehydrogenase [isoleucine degradation] (EC 1.1.1.35);Ontology_term=KEGG_ENZYME:1.1.1.35
# 119                                                        ID=fig|6666666.367937.peg.120;Name=3-ketoacyl-CoA thiolase (EC 2.3.1.16) @ Acetyl-CoA acetyltransferase (EC 2.3.1.9);Ontology_term=KEGG_ENZYME:2.3.1.16,KEGG_ENZYME:2.3.1.9
# 120                                                           ID=fig|6666666.367937.peg.121;Name=Enoyl-CoA hydratase (EC 4.2.1.17) > degradation of branched-chain amino acids and alpha-keto acids;Ontology_term=KEGG_ENZYME:4.2.1.17
# 134                                                                                         ID=fig|6666666.367937.peg.135;Name=Methylcrotonyl-CoA carboxylase biotin-containing subunit (EC 6.4.1.4);Ontology_term=KEGG_ENZYME:6.4.1.4
# 135                                                                                                                 ID=fig|6666666.367937.peg.136;Name=Methylglutaconyl-CoA hydratase (EC 4.2.1.18);Ontology_term=KEGG_ENZYME:4.2.1.18
# 136                                                                                      ID=fig|6666666.367937.peg.137;Name=Methylcrotonyl-CoA carboxylase carboxyl transferase subunit (EC 6.4.1.4);Ontology_term=KEGG_ENZYME:6.4.1.4
# 137                                                                                                                     ID=fig|6666666.367937.peg.138;Name=Isovaleryl-CoA dehydrogenase (EC 1.3.8.4);Ontology_term=KEGG_ENZYME:1.3.8.4
# 139                                                                                                                  ID=fig|6666666.367937.peg.140;Name=Hydroxymethylglutaryl-CoA lyase (EC 4.1.3.4);Ontology_term=KEGG_ENZYME:4.1.3.4
# 144                                                                                                                       ID=fig|6666666.367937.peg.145;Name=Exodeoxyribonuclease III (EC 3.1.11.2);Ontology_term=KEGG_ENZYME:3.1.11.2
# ...                                                                                                                                                                                                                                ...
# 5944                                                                                                                ID=fig|6666666.367937.peg.5945;Name=Diaminopimelate decarboxylase (EC 4.1.1.20);Ontology_term=KEGG_ENZYME:4.1.1.20
# 5945                                                                                                                      ID=fig|6666666.367937.peg.5946;Name=Diaminopimelate epimerase (EC 5.1.1.7);Ontology_term=KEGG_ENZYME:5.1.1.7
# 5948                                                                                                               ID=fig|6666666.367937.peg.5949;Name=2-haloalkanoic acid dehalogenase (EC 3.8.1.2);Ontology_term=KEGG_ENZYME:3.8.1.2
# 5963                                                                                                           ID=fig|6666666.367937.peg.5964;Name=Xanthine phosphoribosyltransferase (EC 2.4.2.22);Ontology_term=KEGG_ENZYME:2.4.2.22
# 5968                                                                                                                 ID=fig|6666666.367937.peg.5969;Name=Phosphoglycolate phosphatase (EC 3.1.3.18);Ontology_term=KEGG_ENZYME:3.1.3.18
# 5970                                                                                                                           ID=fig|6666666.367937.peg.5971;Name=Oligopeptidase A (EC 3.4.24.70);Ontology_term=KEGG_ENZYME:3.4.24.70
# 5975                                                                                                               ID=fig|6666666.367937.peg.5976;Name=Carbonic anhydrase%2C beta class (EC 4.2.1.1);Ontology_term=KEGG_ENZYME:4.2.1.1
# 5978                                                                                                            ID=fig|6666666.367937.peg.5979;Name=Cytochrome c oxidase polypeptide II (EC 1.9.3.1);Ontology_term=KEGG_ENZYME:1.9.3.1
# 5980                                                                                                             ID=fig|6666666.367937.peg.5981;Name=Cytochrome c oxidase polypeptide I (EC 1.9.3.1);Ontology_term=KEGG_ENZYME:1.9.3.1
# 5982                                                                                                           ID=fig|6666666.367937.peg.5983;Name=Cytochrome c oxidase polypeptide III (EC 1.9.3.1);Ontology_term=KEGG_ENZYME:1.9.3.1
# 5987                                                                                 ID=fig|6666666.367937.peg.5988;Name=Heme O synthase%2C protoheme IX farnesyltransferase (EC 2.5.1.-) COX10-CtaB;Ontology_term=KEGG_ENZYME:2.5.1.-
# 5994                                                                                                         ID=fig|6666666.367937.peg.5995;Name=Catalase KatE-intracellular protease (EC 1.11.1.6);Ontology_term=KEGG_ENZYME:1.11.1.6
# 6000                                                                                                                            ID=fig|6666666.367937.peg.6001;Name=Homoserine kinase (EC 2.7.1.39);Ontology_term=KEGG_ENZYME:2.7.1.39
# 6002                                                                                                                               ID=fig|6666666.367937.peg.6003;Name=DNA polymerase I (EC 2.7.7.7);Ontology_term=KEGG_ENZYME:2.7.7.7
# 6009                                                         ID=fig|6666666.367937.peg.6010;Name=N-acetylmuramoyl-L-alanine amidase (EC 3.5.1.28) @ 1%2C6-anhydro-N-acetylmuramyl-L-alanine amidase;Ontology_term=KEGG_ENZYME:3.5.1.28
# 6033                                                                                                              ID=fig|6666666.367937.peg.6034;Name=ATP-dependent DNA helicase RecG (EC 3.6.4.12);Ontology_term=KEGG_ENZYME:3.6.4.12
# 6041  ID=fig|6666666.367937.peg.6042;Name=Guanosine-3'%2C5'-bis(diphosphate) 3'-pyrophosphohydrolase (EC 3.1.7.2) / GTP pyrophosphokinase (EC 2.7.6.5)%2C (p)ppGpp synthetase II;Ontology_term=KEGG_ENZYME:3.1.7.2,KEGG_ENZYME:2.7.6.5
# 6042                                                                                                      ID=fig|6666666.367937.peg.6043;Name=DNA-directed RNA polymerase omega subunit (EC 2.7.7.6);Ontology_term=KEGG_ENZYME:2.7.7.6
# 6043                                                                                                                               ID=fig|6666666.367937.peg.6044;Name=Guanylate kinase (EC 2.7.4.8);Ontology_term=KEGG_ENZYME:2.7.4.8
# 6045                                                                                                                              ID=fig|6666666.367937.peg.6046;Name=Ribonuclease PH (EC 2.7.7.56);Ontology_term=KEGG_ENZYME:2.7.7.56
# 6059                                                                                                                     ID=fig|6666666.367937.peg.6060;Name=Porphobilinogen synthase (EC 4.2.1.24);Ontology_term=KEGG_ENZYME:4.2.1.24
# 6060                                                                                                                           ID=fig|6666666.367937.peg.6061;Name=Polyphosphate kinase (EC 2.7.4.1);Ontology_term=KEGG_ENZYME:2.7.4.1
# 6061                                                                                                                           ID=fig|6666666.367937.peg.6062;Name=Exopolyphosphatase (EC 3.6.1.11);Ontology_term=KEGG_ENZYME:3.6.1.11
# 6070                                                                                   ID=fig|6666666.367937.peg.6071;Name=Aminomethyltransferase (glycine cleavage system T protein) (EC 2.1.2.10);Ontology_term=KEGG_ENZYME:2.1.2.10
# 6076                                                                                                                       ID=fig|6666666.367937.peg.6077;Name=Xaa-Pro aminopeptidase (EC 3.4.11.9);Ontology_term=KEGG_ENZYME:3.4.11.9
# 6080                                                                                                          ID=fig|6666666.367937.peg.6081;Name=5-formyltetrahydrofolate cyclo-ligase (EC 6.3.3.2);Ontology_term=KEGG_ENZYME:6.3.3.2
# 6089                                                                                                 ID=fig|6666666.367937.peg.6090;Name=3-polyprenyl-4-hydroxybenzoate carboxy-lyase (EC 4.1.1.98);Ontology_term=KEGG_ENZYME:4.1.1.98
# 6099                                                                                                                     ID=fig|6666666.367937.peg.6100;Name=Inorganic triphosphatase (EC 3.6.1.25);Ontology_term=KEGG_ENZYME:3.6.1.25
# 6101                                                                                                                  ID=fig|6666666.367937.peg.6102;Name=Acetylornithine deacetylase (EC 3.5.1.16);Ontology_term=KEGG_ENZYME:3.5.1.16
# 6102                                                                                                                     ID=fig|6666666.367937.peg.6103;Name=N-acetylglutamate synthase (EC 2.3.1.1);Ontology_term=KEGG_ENZYME:2.3.1.1
#
# [1349 rows x 9 columns]

# %%
CDS_composition(JCJR2_path, JCJR12_path, ec_number_string='\(EC', specie1='JCJR2', specie2='JCJR12')
# Out:
#           COG  UniProtKB  EC number  Hypothetical protein
# JCJR2   0.365        0.0     21.416                25.448
# JCJR12  0.349        0.0     23.131                26.163

# %%
JCJR2_df[JCJR2_df["attributes"].str.contains('uniprot', flags=re.I)]
# Out:
# Empty DataFrame
# Columns: [seqid, source, type, start, end, score, strand, phase, attributes]
# Index: []

# %%
red_genes_locs12 = Searching_atts(JCJR12_path,potential_reds, False)
red_genes_locs12
# Out:
# defaultdict(None,
#             {'nitroreductase': Int64Index([6310, 6418], dtype='int64'),
#              'aldehyde.+oxidase': Int64Index([], dtype='int64'),
#              'amide.+dehydrogenase': Int64Index([1349, 1350, 2182, 2183, 2620, 3871, 4274, 5102], dtype='int64'),
#              'diaphorase': Int64Index([], dtype='int64'),
#              'hydrogenase': Int64Index([  17,   25,   51,   57,   79,   80,   82,  168,  192,  204,
#                          ...
#                          6259, 6340, 6344, 6346, 6442, 6458, 6510, 6524, 6546, 6555],
#                         dtype='int64', length=272),
#              'xanthine.+oxidase': Int64Index([], dtype='int64'),
#              'cytochrome.+reductase': Int64Index([605, 1311, 1877, 1878, 1903, 3212, 3983, 4106, 5093, 5094, 5095,
#                          6084],
#                         dtype='int64'),
#              'xen[A-Z]': Int64Index([592], dtype='int64'),
#              'PETN': Int64Index([], dtype='int64'),
#              'oxidoreductase': Int64Index([  20,   25,   82,  105,  126,  201,  222,  224,  226,  355,
#                          ...
#                          6210, 6211, 6279, 6456, 6457, 6485, 6512, 6524, 6531, 6546],
#                         dtype='int64', length=118),
#              'xenobiotic': Int64Index([], dtype='int64'),
#              'OYE': Int64Index([5444], dtype='int64'),
#              'flavin oxidoreductase': Int64Index([224, 860, 3135, 5438, 5444, 5588], dtype='int64'),
#              'nitro': Int64Index([267, 268, 3245, 3523, 3641, 4395, 4396, 5250, 5252, 6130, 6257,
#                          6310, 6418],
#                         dtype='int64'),
#              'COG1902': Int64Index([], dtype='int64'),
#              'COG0778': Int64Index([], dtype='int64'),
#              'old yellow': Int64Index([224, 5438], dtype='int64')})

# %%
print(JCJR12_df.iloc[red_genes_locs["flavin oxidoreductase"], 8])
# Out:
# 224      ID=fig|6666666.367945.peg.225;Name=NADH:flavin oxidoreductases%2C Old Yellow Enzyme family
# 860                                ID=fig|6666666.367945.peg.861;Name=NAD(P)H-flavin oxidoreductase
# 3135                        ID=fig|6666666.367945.peg.3136;Name=putative NADH:flavin oxidoreductase
# 5438    ID=fig|6666666.367945.peg.5439;Name=NADH:flavin oxidoreductases%2C Old Yellow Enzyme family
# 5444         ID=fig|6666666.367945.peg.5445;Name=NADH-dependent flavin oxidoreductase%2C Oye family
# 5588                       ID=fig|6666666.367945.peg.5589;Name=NADH-dependent flavin oxidoreductase
# Name: attributes, dtype: object

# %%
print(JCJR12_df.iloc[red_genes_locs['xen[A-Z]'], 8])
# Out:
# 592    ID=fig|6666666.367945.peg.593;Name=Isohexenylglutaconyl-CoA hydratase (EC 4.2.1.57);Ontology_term=KEGG_ENZYME:4.2.1.57
# Name: attributes, dtype: object

# %%
print(JCJR12_df.iloc[red_genes_locs['old yellow'], 8])
# Out:
# 224      ID=fig|6666666.367945.peg.225;Name=NADH:flavin oxidoreductases%2C Old Yellow Enzyme family
# 5438    ID=fig|6666666.367945.peg.5439;Name=NADH:flavin oxidoreductases%2C Old Yellow Enzyme family
# Name: attributes, dtype: object

# %%
red_genes_locs2 = Searching_atts(JCJR2_path,potential_reds, False)
red_genes_locs2
# Out:
# defaultdict(None,
#             {'nitroreductase': Int64Index([4041, 4427], dtype='int64'),
#              'aldehyde.+oxidase': Int64Index([], dtype='int64'),
#              'amide.+dehydrogenase': Int64Index([22, 1283, 2014, 2015, 3954, 5019], dtype='int64'),
#              'diaphorase': Int64Index([], dtype='int64'),
#              'hydrogenase': Int64Index([  14,   18,   19,   20,   21,   22,   67,  102,  103,  118,
#                          ...
#                          5762, 5763, 5782, 5787, 5809, 5817, 5821, 5912, 5913, 5930],
#                         dtype='int64', length=238),
#              'xanthine.+oxidase': Int64Index([], dtype='int64'),
#              'cytochrome.+reductase': Int64Index([764, 1717, 1871, 4153, 4154, 4155, 5988], dtype='int64'),
#              'xen[A-Z]': Int64Index([420, 3307, 4587], dtype='int64'),
#              'PETN': Int64Index([], dtype='int64'),
#              'oxidoreductase': Int64Index([  15,   37,  133,  149,  157,  204,  219,  267,  301,  322,  367,
#                           385,  387,  456,  464,  527,  531,  718,  764,  912,  913,  915,
#                          1156, 1259, 1308, 1775, 1845, 1846, 1901, 1971, 2033, 2154, 2155,
#                          2156, 2521, 2569, 2779, 2880, 2897, 3043, 3044, 3066, 3153, 3174,
#                          3288, 3376, 3390, 3516, 3522, 3523, 3625, 3629, 3653, 3687, 3716,
#                          3757, 3758, 3789, 3790, 3791, 3792, 3793, 3794, 3795, 3796, 3797,
#                          3798, 3799, 3800, 3801, 3863, 3868, 3878, 3879, 3888, 3902, 3906,
#                          3970, 3980, 4009, 4094, 4102, 4259, 4299, 4453, 4665, 4688, 4725,
#                          4912, 4939, 4968, 5372, 5401, 5460, 5518, 5519, 5757, 5763, 5965,
#                          6084],
#                         dtype='int64'),
#              'xenobiotic': Int64Index([420, 3307, 4587], dtype='int64'),
#              'OYE': Int64Index([1259], dtype='int64'),
#              'flavin oxidoreductase': Int64Index([456, 1259, 3716, 3878], dtype='int64'),
#              'nitro': Int64Index([1079, 1408, 2406, 2408, 2533, 3472, 3473, 4041, 4297, 4390, 4391,
#                          4427, 4796, 5952],
#                         dtype='int64'),
#              'COG1902': Int64Index([], dtype='int64'),
#              'COG0778': Int64Index([], dtype='int64'),
#              'old yellow': Int64Index([], dtype='int64')})

# %%
print(JCJR2_df.iloc[red_genes_locs["flavin oxidoreductase"], 8])
# Out:
# 224     ID=fig|6666666.367937.peg.225;Name=ABC transporter%2C ATP-binding protein (cluster 5%2C nickel/peptides/opines) / ABC transporter%2C ATP-binding protein (cluster 5%2C nickel/peptides/opines)
# 860                                                                              ID=fig|6666666.367937.peg.861;Name=Gamma-butyrobetaine dioxygenase (EC 1.14.11.1);Ontology_term=KEGG_ENZYME:1.14.11.1
# 3135                                                           ID=fig|6666666.367937.peg.3136;Name=Phytochrome%2C two-component sensor histidine kinase (EC 2.7.3.-);Ontology_term=KEGG_ENZYME:2.7.3.-
# 5438                                                                                                                                          ID=fig|6666666.367937.peg.5439;Name=hypothetical protein
# 5444                                                                                                                                        ID=fig|6666666.367937.peg.5445;Name=Mobile element protein
# 5588                                                                                                                                          ID=fig|6666666.367937.peg.5589;Name=hypothetical protein
# Name: attributes, dtype: object

# %%
JCJR2_df[JCJR2_df["attributes"].str.contains("peg.3146")]
# Out:
#           seqid source type  start   end score strand phase  \
# 3145  contig_26    FIG  CDS   6274  6486     .      +     1
#
#                                                     attributes
# 3145  ID=fig|6666666.367937.peg.3146;Name=hypothetical protein

# %%
JCJR2_df[JCJR2_df["attributes"].str.contains("xenobiotic", case=False)]+
# Out:
#           seqid source type   start     end score strand phase  \
# 420    contig_1    FIG  CDS  443870  444958     .      +     2
# 3307  contig_27    FIG  CDS   89275   90324     .      +     1
# 4587   contig_4    FIG  CDS  194253  195359     .      -     0
#
#                                                                 attributes
# 420              ID=fig|6666666.367937.peg.421;Name=xenobiotic reductase A
# 3307            ID=fig|6666666.367937.peg.3308;Name=Xenobiotic reductase B
# 4587  ID=fig|6666666.367937.peg.4588;Name=xenobiotic reductase%2C putative

# %% [markdown]
# **Angi encontro Xen A y B en mandelii (JCJR12), yo no**

# %%
JCJR12_df[JCJR12_df["attributes"].str.contains("xenobiotic", case=False)]
# Out:
# Empty DataFrame
# Columns: [seqid, source, type, start, end, score, strand, phase, attributes]
# Index: []

# %% [markdown]
# al buscar la secuencia aminoacidica en mi `.faa` la encuentro en el siguiente contig/peg **peg.5822**

# %%
JCJR12_df[JCJR12_df["attributes"].str.contains("peg.5822")]
# Out:
#                  seqid source type   start     end score strand phase  \
# 5821  contig7|mandelii    FIG  CDS  293477  294526     .      -     2
#
#                                                                                                          attributes
# 5821  ID=fig|6666666.367945.peg.5822;Name=N-ethylmaleimide reductase (EC 1.-.-.-);Ontology_term=KEGG_ENZYME:1.-.-.-

# %%
# Out:
# E2_sequence_Biopython.ipynb  TNT_Rast_gffs.ipynb

# %%
ls -ltrh
# Out:
# total 2152
# -rw-r--r--  1 cbib-02  staff   869K Sep  4 16:32 E2_sequence_Biopython.ipynb
# -rw-r--r--  1 cbib-02  staff   201K Sep 24 16:51 TNT_Rast_gffs.ipynb

# %% [markdown]
# ### Angi gffs

# %%
JCJR2_path = '/Users/cbib-02/Documents/TNT/JCJR2/Rastk/6666666.320807_pseudo.gff'
JCJR12_path = '/Users/cbib-02/Documents/TNT/JCJR12/Rastk/6666666.320830_mandelii.gff'

# %%
JCJR2_df = Fastd_to_pandas(JCJR2_path)
JCJR12_df = Fastd_to_pandas(JCJR12_path)
print(JCJR2_df.shape, JCJR12_df.shape)
JCJR2_df.head()
# Out:
# (5985, 9) (6351, 9)
#       seqid source type  start   end score strand phase  \
# 0  contig_1    FIG  CDS    785  2413     .      +     2
# 1  contig_1    FIG  CDS   2425  4047     .      -     1
# 2  contig_1    FIG  CDS   4324  5292     .      -     1
# 3  contig_1    FIG  CDS   5342  6271     .      -     2
# 4  contig_1    FIG  CDS   6525  7559     .      +     0
#
#                                                                                                             attributes
# 0  ID=fig|6666666.320807.peg.1;Name=diguanylate cyclase/phosphodiesterase (GGDEF & EAL domains) with PAS/PAC sensor(s)
# 1                ID=fig|6666666.320807.peg.2;Name=Methyl-accepting chemotaxis protein I (serine chemoreceptor protein)
# 2                    ID=fig|6666666.320807.peg.3;Name=Methyltransferase (EC 2.1.1.-);Ontology_term=KEGG_ENZYME:2.1.1.-
# 3                                                              ID=fig|6666666.320807.peg.4;Name=FIG040954: Transporter
# 4            ID=fig|6666666.320807.peg.5;Name=Selenide%2Cwater dikinase (EC 2.7.9.3);Ontology_term=KEGG_ENZYME:2.7.9.3

# %%
print(Unique_types_sources(JCJR12_path), Unique_types_sources(JCJR2_path))
# Out:
# Unique types ['CDS' 'tRNA' 'rRNA']
# Unique sources ['FIG']
# Unique types ['CDS' 'tRNA' 'rRNA']
# Unique sources ['FIG']

# %%
Type_counts(JCJR2_path, JCJR12_path, specie1='JCJR2', specie2='JCJR12')
# Out:
#       JCJR2  JCJR12
# CDS    5781    6138
# rRNA     30      30
# tRNA    174     183

# %%
common_prods_jcjr2 = Most_common_products(JCJR2_path)
print('\n')
common_prods_jcjr12 = Most_common_products(JCJR12_path)
# Out:
# [('Name=hypothetical protein', 684),
#  ('Name=Transcriptional regulator%2C LysR family', 35),
#  ('Name=Transcriptional regulator%2C AraC family', 29),
#  ('Name=Transcriptional regulator%2C TetR family', 25),
#  ('Name=Methyl-accepting chemotaxis protein I (serine chemoreceptor protein)',
#   24),
#  ('Name=Permeases of the major facilitator superfamily', 24),
#  ('Name=Mobile element protein', 24),
#  ('Name=5S RNA', 24),
#  ('Name=membrane protein%2C putative', 20),
#  ('Name=Phosphonate ABC transporter phosphate-binding periplasmic component '
#   '(TC 3.A.1.9.1)',
#   19)]
#
#
# [('Name=hypothetical protein', 647),
#  ('Name=Transcriptional regulator%2C LysR family', 50),
#  ('Name=Mobile element protein', 32),
#  ('Name=Transcriptional regulator%2C AraC family', 30),
#  ('Name=Phosphonate ABC transporter phosphate-binding periplasmic component '
#   '(TC 3.A.1.9.1)',
#   27),
#  ('Name=5S RNA', 24),
#  ('Name=Transcriptional regulator%2C TetR family', 23),
#  ('Name=diguanylate cyclase/phosphodiesterase (GGDEF & EAL domains) with '
#   'PAS/PAC sensor(s)',
#   19),
#  ('Name=Permease of the drug/metabolite transporter (DMT) superfamily', 17),
#  ('Name=3-oxoacyl-[acyl-carrier protein] reductase (EC 1.1.1.100)', 16)]

# %%
CDS_composition(JCJR2_path, JCJR12_path, ec_number_string='\(EC', specie1='JCJR2', specie2='JCJR12')
# Out:
#           COG  UniProtKB  EC number  Hypothetical protein
# JCJR2   0.735        0.0     23.659                18.062
# JCJR12  0.769        0.0     25.564                19.198

# %%
JCJR12_df[JCJR12_df["attributes"].str.contains("xenobiotic", case=False)]
# Out:
#          seqid source type   start     end score strand phase  \
# 1319  contig10    FIG  CDS  212708  213799     .      -     2
# 5056   contig6    FIG  CDS  349097  350188     .      +     2
#
#                                                       attributes
# 1319  ID=fig|6666666.320830.peg.1320;Name=xenobiotic reductase A
# 5056  ID=fig|6666666.320830.peg.5059;Name=xenobiotic reductase A

# %%
JCJR2_df[JCJR2_df["attributes"].str.contains("xenobiotic", case=False)]
# Out:
#         seqid source type   start     end score strand phase  \
# 410  contig_1    FIG  CDS  443870  444958     .      +     2
#
#                                                     attributes
# 410  ID=fig|6666666.320807.peg.411;Name=xenobiotic reductase A
